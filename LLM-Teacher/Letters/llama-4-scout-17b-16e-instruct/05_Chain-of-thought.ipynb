# %%
import pandas as pd
import json, re
import matplotlib.pyplot as plt
from ibm_watsonx_ai import Credentials, APIClient
from ibm_watsonx_ai.foundation_models import ModelInference
from ibm_watsonx_ai.foundation_models.schema import TextGenParameters
from decouple import Config, RepositoryEnv

# %%
# Load the environment variables using python-decouple
# The .env file should be in the root of the project
# The .env file should NOT be committed to the repository

config = Config(RepositoryEnv(".env.paul"))

# Load the credentials
WX_API_KEY = config("WX_API_KEY")

# %%
credentials = Credentials(
    url = "https://us-south.ml.cloud.ibm.com",
    api_key = WX_API_KEY
)
client = APIClient(
    credentials=credentials, 
    project_id="68126b74-155e-4a70-aa2c-1781dfad87f6"
)

# %%
# --- Setup the Model ---
params = TextGenParameters(
    temperature=0.05,           # Light creativity
    max_new_tokens=300          # Enough for descriptive text
)

model = ModelInference(
    api_client=client,
    params=params,
    model_id="meta-llama/llama-4-scout-17b-16e-instruct"
)

# %%
def create_prompt(sign_name: str) -> str:
    return (
        f"You are an American Sign Language (ASL) teacher.\n\n"
        f"Your task is to explain how to perform the ASL sign for the letter '{sign_name}' in a clear and simple way. Do not assume any prior knowledge about ASL \n\n"
        f"Think step-by-step how to teach the sign for the letter “{sign_name}”. Think about handshape, orientation, and movement of the hand.\n"
        f"Think about the positions of each finger and how they should be held.\n\n"
        f"After thinking, clearly explain how to perform the ASL sign on a beginner level for the letter '{sign_name}'.\n\n"
        f"Only output the explanation for the requested sign once. If appropriate, use less tokens than available. Do not include any other text. Ensure that you exlusively explain the sign for the letter '{sign_name}'\n\n"
    )

# %%
# --- Generate ASL Description ---
def generate_asl_description(sign_name: str) -> str:
    prompt = create_prompt(sign_name)
    
    response = model.generate(prompt=prompt)
    generated_text = response['results'][0]['generated_text']
    
    return generated_text

# %% [markdown]
# Judge

# %%
# Separate model instance for evaluation (judge), we are always using llama-3-3-70b-instruct based on literature review
params = TextGenParameters(
    temperature=0.01,
    max_new_tokens=100,
)


judge_model = ModelInference(
    api_client=client,
    params=params, 
    model_id="meta-llama/llama-3-3-70b-instruct",
)

# %% [markdown]
# Mass evaluation

# %%
def create_comparison_judge_prompt(sign_name: str, generated_description: str, expected_description: str, guardrails="json") -> str:
    return f"""You are evaluating the quality of a generated ASL sign description based on 3 criteria by comparing it to a ground truth.

Sign: "{sign_name}"

Expected (ground truth) description:
"{expected_description}"

Generated description:
"{generated_description}"

The criteria are:
1. Faithfulness: The content of the generated description can be interfered from the content of the ground truth.
2. Answer Relevance: The generated description specifically and sufficiently describes the requested sign.
3. Context Relevance: The generated description exclusively contains information that is needed to describe the sign.

Grade each criterion from 0 to 1:
- 1 - The generated description fully meets the criterion
- 0.5 - The generated description partially meets the criterion
- 0 - The generated description does not meet the criterion

Do not downgrade the generated description for variation in wording or style. 

Here are a few examples of how to answer:
- example 1:
  - expected description "Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."
  - generated description "To sign the letter X in American Sign Language (ASL), make a fist with your dominant hand. Extend your index finger and bend only the tip forward to form a small hook. Face your palm forward so the hooked index finger is visible"
  - response: "faithfulness": 1, "answer_relevance": 1, "context_relevance": 1
- example 2:
  - expected description "Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."
  - generated description "Dance in a circle like you never danced before."
  - response: "faithfulness": 0, "answer_relevance": 0, "context_relevance": 0
- example 3:
  - expected description "Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."
  - generated description "To sign the letter X in American Sign Language (ASL), make a fist with your dominant hand. Extend your index finger and bend only the tip forward to form a small hook."
  - response: "faithfulness": 1, "answer_relevance": 1, "context_relevance": 1
- example 4:
  - expected description "Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."
  - generated description "Hello user, this is a great question. I also love to make the sign for the letter 'X'. To sign the letter X in American Sign Language (ASL), make a fist with your dominant hand. Extend your index finger and bend only the tip forward to form a small hook."
  - response: "faithfulness": 0.5, "answer_relevance": 1, "context_relevance": 0.5
- example 5:
  - expected description Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."
  - generated description "To sign the letter X in American Sign Language (ASL), make a fist with your dominant hand and extend your index finger"
  - response: "faithfulness": 1, "answer_relevance": 0.5, "context_relevance": 1
- example 6:
  - expected description "Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."
  - generated description "To sign the letter X in American Sign Language (ASL), make a fist with your dominant hand. Extend your index finger and bend only the tip forward to form a small hook. Keep your thumb resting against the side of your curled middle finger. The middle, ring, and pinky fingers stay curled into the palm. There is no movement; the hand remains still"
  - response: "faithfulness": 1, "answer_relevance": 1, "context_relevance": 0.5

Think carefully for each criterion before answering.

Respond only in the following format, enclosed within <output> tags:

<output>
{{
  "faithfulness": <0, 0.5, or 1>,
  "answer_relevance": <0, 0.5, or 1>,
  "context_relevance": <0, 0.5, or 1>
}}
</output>
"""

# %%
def evaluate_against_ground_truth(sign_name: str, generated_description: str, expected_description: str) -> dict:
    prompt = create_comparison_judge_prompt(sign_name, generated_description, expected_description)

    def try_parse_response(response_text: str) -> dict:
        result = {
            "faithfulness": None,
            "answer_relevance": None,
            "context_relevance": None
        }

        # Try direct parse
        try:
            # Strip leading text if any
            json_start = response_text.find("{")
            if json_start != -1:
                response_text = response_text[json_start:]

            parsed = json.loads(response_text)
            if isinstance(parsed, dict):
                result.update(parsed)
                return result
        except Exception:
            pass

        # Try fallback regex
        matches = re.findall(r"\{.*?\}", response_text, re.DOTALL)
        for match in matches:
            try:
                parsed = json.loads(match)
                if isinstance(parsed, dict):
                    result.update(parsed)
                    return result
            except Exception as e:
                continue

        return result  # fallback with None values if all fails

    # First attempt
    response = judge_model.generate(prompt=prompt)
    judged_text = response['results'][0]['generated_text']
    result = try_parse_response(judged_text)

    # Retry once if parsing failed
    if any(v is None for v in result.values()):
        print(f" First parse failed for sign '{sign_name}', retrying once...")
        response_retry = judge_model.generate(prompt=prompt)
        judged_text_retry = response_retry['results'][0]['generated_text']
        result = try_parse_response(judged_text_retry)

    # Final message if still failing
    if any(v is None for v in result.values()):
        print(f" Failed to parse JSON after retry for sign: '{sign_name}'.")

    return result

# %%
#Testing judge with manual input
sign = "hello"
expected = "Begin with the side of your index finger against your forehead and then move your hand up and away from your head."
generated = "Start with the side of your index touching your forehead, then extend your pinky"

scores = evaluate_against_ground_truth(sign, generated, expected)

print("\nJudge Result:")
print(f"Faithfulness: {scores['faithfulness']}")
print(f"Answer Relevance: {scores['answer_relevance']}")
print(f"Context Relevance: {scores['context_relevance']}")
# Out:
# Judge Result:
# Faithfulness: 0.5
# Answer Relevance: 0.5
# Context Relevance: 0.5

# %%
test_data = [
    {"sign": "A", "expected": "Thumb: Curled alongside the side of the index finger, resting against it. Index: Bent downward into the palm, creating a firm curve. Middle: Bent downward in line with the index. Ring: Bent downward. Pinky: Bent downward. Palm Orientation: Facing forward (away from your body). Wrist/Forearm: Neutral position; elbow bent naturally. Movement: None. Note: Represents the shape of a capital 'A'."},
    {"sign": "B", "expected": "Thumb: Folded tightly across the center of the palm, held flat. Index: Extended straight up and held close to the middle finger. Middle: Extended straight up next to the index finger. Ring: Extended straight up next to the middle finger. Pinky: Extended straight up, close to the ring finger. Palm Orientation: Facing forward. Wrist/Forearm: Upright, fingers vertical. Movement: None. Note: Resembles the vertical line of the letter 'B'."},
    {"sign": "C", "expected": "Thumb: Curved naturally to oppose the fingers and help form a half-circle. Index: Curved downward and to the side to help form the top of the 'C'. Middle: Curved to follow the shape created by the index. Ring: Curved in alignment with the rest to form the side of the 'C'. Pinky: Curved slightly to close the 'C' shape. Palm Orientation: Slightly angled outward (to mimic letter curvature). Wrist/Forearm: Slight bend at wrist to angle the 'C'. Movement: None. Note: Entire hand forms a visible capital letter 'C'."},
    {"sign": "D", "expected": "Thumb: Pads rest against the tips of the middle, ring, and pinky fingers. Index: Fully extended upward and isolated from other fingers. Middle: Curved downward to meet the thumb. Ring: Curved downward to meet the thumb. Pinky: Curved downward to meet the thumb. Palm Orientation: Facing forward. Wrist/Forearm: Neutral vertical. Movement: None. Note: Mimics the shape of a capital 'D' with the index as the upright line."},
    {"sign": "E", "expected": "Thumb: Pressed against the palm and touching curled fingers from below. Index: Curled downward toward the palm to meet the thumb. Middle: Curled downward toward the palm. Ring: Curled downward toward the palm. Pinky: Curled downward toward the palm. Palm Orientation: Facing forward. Wrist: Neutral or slightly rotated outward. Movement: None. Note: Shape resembles the loop and middle bar of the letter 'E'."},
    {"sign": "F", "expected": "Thumb: Touches tip of the index finger to form a closed circle. Index: Touches the thumb to complete the circle. Middle: Extended straight up and relaxed, slightly separated. Ring: Extended straight up and relaxed, slightly separated. Pinky: Extended straight up and relaxed, slightly separated. Palm Orientation: Facing forward. Wrist: Neutral to slightly outward. Movement: None. Note: The circle represents the opening in the letter 'F'."},
    {"sign": "G", "expected": "Thumb: Extended sideways, parallel to index. Index: Extended sideways, forming a flat, straight line with thumb. Middle: Folded inward against the palm. Ring: Folded inward against the palm. Pinky: Folded inward against the palm. Palm Orientation: Inward (side of hand faces viewer). Wrist: Horizontal; hand like a gun shape. Movement: None. Note: Emulates the lower stroke of a 'G'."},
    {"sign": "H", "expected": "Thumb: Tucked over curled ring and pinky. Index: Extended to the side. Middle: Extended to the side, beside index. Ring: Curled tightly in palm. Pinky: Curled tightly in palm. Palm Orientation: Facing down or slightly out. Wrist: Flat or slightly turned. Movement: None. Note: Represents two parallel lines, like a sideways 'H'."},
    {"sign": "I", "expected": "Thumb: Folded across or tucked alongside curled fingers. Index: Curled into the palm. Middle: Curled into the palm. Ring: Curled into the palm. Pinky: Extended straight up. Palm Orientation: Facing forward. Wrist: Neutral vertical. Movement: None. Note: Pinky alone resembles a lowercase 'i'."},
    {"sign": "J", "expected": "Thumb: Folded against curled fingers. Index: Curled into the palm. Middle: Curled into the palm. Ring: Curled into the palm. Pinky: Extended and used to trace a 'J' in the air. Palm Orientation: Starts forward, rotates slightly. Movement: Trace 'J' downward, left, then up. Note: Motion is essential to identify this as 'J'."},
    {"sign": "K", "expected": "Thumb: Between index and middle fingers, touching base of middle. Index: Extended diagonally upward. Middle: Extended diagonally upward, apart from index. Ring: Curled into palm. Pinky: Curled into palm. Palm Orientation: Facing out or slightly angled. Wrist: Upright or angled. Movement: None. Note: Mimics the open shape of the letter 'K'."},
    {"sign": "L", "expected": "Thumb: Extended horizontally. Index: Extended vertically. Middle: Curled into palm. Ring: Curled into palm. Pinky: Curled into palm. Palm Orientation: Facing forward. Wrist: Upright. Movement: None. Note: Clearly forms a visual 'L'."},
    {"sign": "M", "expected": "Thumb: Tucked under index, middle, and ring fingers. Index: Folded over the thumb. Middle: Folded over the thumb. Ring: Folded over the thumb. Pinky: Curled beside ring or relaxed. Palm Orientation: Facing out. Wrist: Neutral. Movement: None. Note: Three fingers over thumb = 3 strokes = 'M'."},
    {"sign": "N", "expected": "Thumb: Tucked under index and middle fingers. Index: Folded over thumb. Middle: Folded over thumb. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing out. Movement: None. Note: Two fingers over thumb = 2 strokes = 'N'."},
    {"sign": "O", "expected": "Thumb: Curved inward to meet fingertips. Index: Curved downward to meet thumb. Middle: Curved downward to meet thumb. Ring: Curved downward to meet thumb. Pinky: Curved downward to meet thumb. Palm Orientation: Facing forward. Wrist: Upright or slightly turned. Movement: None. Note: Clear circular 'O' shape."},
    {"sign": "P", "expected": "Thumb: Between and touching middle finger. Index: Extended downward and slightly angled. Middle: Extended and separated from index. Ring: Folded into the palm. Pinky: Folded into the palm. Palm Orientation: Tilted downward. Wrist: Bent downward. Movement: None. Note: Downward angle distinguishes from K."},
    {"sign": "Q", "expected": "Thumb: Parallel to index. Index: Points downward. Middle: Curled into palm. Ring: Curled into palm. Pinky: Curled into palm. Palm Orientation: Downward. Wrist: Bent downward. Movement: None. Note: Like G but rotated to point down."},
    {"sign": "R", "expected": "Thumb: Resting against curled fingers. Index: Crossed over middle finger tightly. Middle: Crossed under index. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Finger crossing symbolizes 'R'."},
    {"sign": "S", "expected": "Thumb: Crossed tightly over the front of curled fingers. Index: Curled into a fist. Middle: Curled into a fist. Ring: Curled into a fist. Pinky: Curled into a fist. Palm Orientation: Facing forward. Wrist: Upright. Movement: None. Note: Fist shape resembles bold 'S'."},
    {"sign": "T", "expected": "Thumb: Inserted between index and middle fingers. Index: Curled downward over the thumb. Middle: Curled downward over the thumb. Ring: Curled into the palm. Pinky: Curled into the palm. Palm Orientation: Facing forward. Movement: None. Note: Thumb poking between fingers resembles old-style 'T'."},
    {"sign": "U", "expected": "Thumb: Folded against palm. Index: Extended straight upward. Middle: Extended straight upward, held together with index. Ring: Folded into the palm. Pinky: Folded into the palm. Palm Orientation: Facing forward. Movement: None. Note: Two fingers = 2 strokes of 'U'."},
    {"sign": "V", "expected": "Thumb: Folded in or at side. Index: Extended upward. Middle: Extended upward, spread apart from index. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Clear 'V' shape."},
    {"sign": "W", "expected": "Thumb: Tucked or relaxed. Index: Extended upward. Middle: Extended upward. Ring: Extended upward, spread slightly. Pinky: Folded into the palm. Palm Orientation: Facing forward. Movement: None. Note: Three fingers = 'W'."},
    {"sign": "X", "expected": "Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."},
    {"sign": "Y", "expected": "Thumb: Extended sideways. Index: Folded into palm. Middle: Folded into palm. Ring: Folded into palm. Pinky: Extended in opposite direction from thumb. Palm Orientation: Facing forward. Movement: None. Note: Thumb and pinky spread = 'Y' shape."},
    {"sign": "Z", "expected": "Thumb: Folded against curled fingers or at the side. Index: Extended and used to draw a 'Z' in the air. Middle: Curled into palm. Ring: Curled into palm. Pinky: Curled into palm. Palm Orientation: Faces slightly forward, rotating with the movement. Movement: Trace 'Z' in air from top-left to bottom-right."}
]

# %%
# Store all scores
all_scores = []

# Counter to indicate progress of the evaluation
i = 0

for entry in test_data:
    i += 1
    print(f"\n{i}. Evaluating sign: {entry['sign']}")
    sign = entry["sign"]
    expected = entry["expected"]

    # Generate from LLM
    generated = generate_asl_description(sign)

    # Print the generated description
    print(f"  Generated Description: {generated}")

    # Judge against expected
    scores = evaluate_against_ground_truth(sign, generated, expected)
    all_scores.append(scores)

    # Print individual scores
    print(f"  Faithfulness: {scores['faithfulness']}")
    print(f"  Answer Relevance: {scores['answer_relevance']}")
    print(f"  Context Relevance: {scores['context_relevance']}")

# Compute and print average for each metric
print("\nAverage Scores:")
faithfulness_avg = sum(s["faithfulness"] for s in all_scores if s["faithfulness"] is not None) / len(all_scores)
print(f"Faithfulness: {faithfulness_avg:.2f}")
relevance_avg = sum(s["answer_relevance"] for s in all_scores if s["answer_relevance"] is not None) / len(all_scores)
print(f"Answer Relevance: {relevance_avg:.2f}")
context_avg = sum(s["context_relevance"] for s in all_scores if s["context_relevance"] is not None) / len(all_scores)
print(f"Context Relevance: {context_avg:.2f}")
# Out:
# 1. Evaluating sign: A
#   Generated Description: To make the sign for the letter 'A' in ASL, start with your dominant hand and make a fist. Extend your thumb, pinky finger, and keep the rest of your fingers curled into your palm. The thumb should be extended out to the side, not in front of you, and not touching your other fingers. Your pinky should be extended but relaxed, not stiff. The orientation of your hand should be with your palm facing forward and your wrist straight. There is no movement for this sign; simply hold the handshape in place.
#   Faithfulness: 0.5
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 2. Evaluating sign: B
#   Generated Description: To make the sign for the letter 'B' in ASL, start with your dominant hand and make a fist. Extend your thumb, pinky, and index finger, while keeping your middle and ring fingers bent down toward your palm. The thumb should be on the side of your index finger. Your hand should be in a neutral position, with your palm facing your body. There is no movement needed for this sign; simply hold the handshape.
#   Faithfulness: 0
#   Answer Relevance: 0.5
#   Context Relevance: 0.5
#
# 3. Evaluating sign: C
#   Generated Description: To make the sign for the letter 'C' in ASL, start by holding your dominant hand up with your palm facing forward. Make a fist with your hand, but keep your thumb on the outside of your fingers. Your thumb should be on top of your fingers, not tucked inside the fist. Your index finger, middle finger, ring finger, and pinky finger should all be together, and your thumb should be opposite them, on the other side of your hand. The shape of your hand should resemble the letter 'C'. There is no movement needed for this sign; simply hold the handshape.
#   Faithfulness: 0.5
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 4. Evaluating sign: D
#   Generated Description: To make the sign for the letter 'D' in ASL, start with your dominant hand and make a fist. Extend your thumb and pinky finger, keeping them straight, while tucking your index, middle, and ring fingers into your palm. The thumb and pinky should be parallel to each other. Your thumb should be on top and your pinky on the bottom, with your palm facing forward and slightly outward. There should be no movement; hold this position steady.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 5. Evaluating sign: E
#   Generated Description: To make the sign for the letter 'E' in ASL, start with your dominant hand and hold it out in front of you. Make a fist with your hand, but keep your pinky finger extended upwards. Keep your thumb against the side of your index and middle fingers. Your ring finger should also be tucked in towards your palm, similar to your pinky. The tip of your extended pinky should be pointing upwards, and your wrist should be relaxed. There is no movement needed for this sign; simply hold the handshape in place.
#   Faithfulness: 0
#   Answer Relevance: 0.5
#   Context Relevance: 0.5
#
# 6. Evaluating sign: F
#   Generated Description: To make the sign for the letter 'F' in ASL, start with your dominant hand and make a fist. Extend your thumb, index finger, and pinky finger, while keeping your middle and ring fingers tucked into your palm. The thumb should be on the side of your hand, not on top of your fingers. The index finger should be pointing upwards. Hold your hand in front of you at shoulder height, with your palm facing forward. Keeping the handshape, move your hand slightly to the left and right, but not too far, just a small movement.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 7. Evaluating sign: G
#   Generated Description: To make the sign for the letter 'G' in ASL, start with your dominant hand and hold it out in front of you. Make a fist with your hand, but extend your thumb and pinky finger, keeping them straight. Your thumb should be on top and your pinky finger on the bottom. The other fingers - your index, middle, and ring fingers - should be curled into your palm. Now, move your hand so your thumb is pointing upwards, with your pinky finger pointing downwards. Your wrist and forearm should be relaxed. That's the sign for the letter 'G' in ASL.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 8. Evaluating sign: H
#   Generated Description: To make the sign for the letter 'H' in ASL, start by holding your dominant hand up with your palm facing forward. Make a flat 'O' shape with your hand by touching your thumb to the top of your index finger, while keeping the other fingers straight and sticking out. Your thumb and index finger should form a circle, but not touch the other fingers. The middle, ring, and pinky fingers should be extended and not bent. Now, move your hand to the right and then back to the left, keeping your wrist straight and your hand flat. As you move your hand, keep the 'O' shape and make sure your thumb and index finger stay in contact. This movement should be smooth and controlled.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 9. Evaluating sign: I
#   Generated Description: To perform the ASL sign for the letter 'I', start by holding up your pinky, ring, middle, and thumb fingers, while keeping your index finger extended upwards, pointing straight up towards the ceiling. Your hand should be in a relaxed position, with your wrist straight. The extended index finger should be the only one pointing up, while the other fingers are tucked in. This specific handshape represents the letter 'I' in ASL. There is no movement required for this sign; simply hold the handshape in place.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 10. Evaluating sign: J
#   Generated Description: To perform the ASL sign for the letter 'J', start with your dominant hand and make a fist with all fingers curled in towards your palm, except for your pinky finger which should be extended straight out. Your thumb should be tucked into the side of your fist. The orientation of your hand should be with your palm facing towards you. Now, move your extended pinky finger down, so it points towards the ground, forming a hook-like shape, then bring it back up to the starting position, making a small downward and upward movement. This movement should be smooth and controlled.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 11. Evaluating sign: K
#   Generated Description: To make the sign for the letter 'K' in ASL, start with your dominant hand and hold it out in front of you. Make a fist with your hand, but extend your pinky and thumb. Keep your pinky finger straight and your thumb pointing upwards, away from your palm. Your index, middle, and ring fingers should be curled into your palm. The tip of your thumb should be close to the tip of your pinky. Your wrist and forearm should be relaxed. With this handshape, move your hand slightly to the side, but not too far, just a small movement. The orientation of your hand is important, with your palm facing forward and to the side, slightly away from your body.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 12. Evaluating sign: L
#   Generated Description: To make the sign for the letter 'L', start by holding your dominant hand up with your palm facing inward, toward your body. Make a fist with your hand, but keep your pinky finger extended downward, pointing away from you. Your thumb should be tucked into your palm, resting on top of your other fingers. The index, middle, and ring fingers should be held together and bent at the knuckles, forming a tight fist shape with them. The extended pinky finger should be straight and not bent. Keep your wrist straight and your forearm parallel to the ground. With this handshape, orientation, and position, you have formed the ASL sign for the letter 'L'.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 13. Evaluating sign: M
#   Generated Description: To make the sign for the letter 'M' in ASL, start by holding your dominant hand up with your palm facing you. Make a fist with your hand, but keep your thumb on the outside of your fingers. Your index, middle, and ring fingers should be together and bent down toward your palm, while your pinky finger is also bent down but slightly separated from the other fingers. Your thumb should be resting on top of your index finger. From this position, simply move your hand straight out from your body, keeping the same handshape and orientation, and then bring it back to the starting position near your body. Repeat this movement a couple of times if needed for emphasis, but the basic sign is a single movement out and back.
#   Faithfulness: 0.5
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 14. Evaluating sign: N
#   Generated Description: To make the sign for the letter 'N' in ASL, start by holding your dominant hand up with your palm facing forward. Make a flat 'O' shape with your hand by touching the tip of your thumb to the tip of your index finger, while keeping the other fingers straight and sticking out. Your thumb and index finger should be bent, forming a circle, but not a complete one, as the other fingers remain extended. Now, move your hand slightly outward, about an inch or two, while keeping the same handshape and orientation. This movement should be small and controlled.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 15. Evaluating sign: O
#   Generated Description: To make the sign for the letter 'O' in ASL, start by holding your dominant hand up with your palm facing forward. Make a circle with your thumb and index finger, while keeping your other fingers straight and extended out of the way. Your thumb and index finger should touch, forming a complete circle. The other fingers, including your middle finger, ring finger, and pinky, should be straight and not touching the circle made by your thumb and index finger. There should be no movement; hold the handshape steady.
#   Faithfulness: 0.5
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 16. Evaluating sign: P
#   Generated Description: To make the sign for the letter 'P' in ASL, start with your dominant hand and hold it out in front of you. Make a fist with your hand, but keep your pinky finger extended out to the side, away from your other fingers. The pinky finger should be straight and not bent. Your thumb should be resting on top of your fingers, not sticking out. The orientation of your hand is with your palm facing towards you or slightly inward. There is little to no movement in this sign; simply hold the handshape in place.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 17. Evaluating sign: Q
#   Generated Description: To make the sign for the letter 'Q' in ASL, start with your dominant hand and hold it out in front of you. Make a fist with your hand, but keep your pinky finger extended and pointed upwards, while keeping your thumb resting on top of your index and middle fingers. The ring finger should also be extended and pointed upwards, parallel to your pinky finger. Your wrist should be relaxed. There is no movement needed for this sign; simply hold the handshape in place.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 18. Evaluating sign: R
#   Generated Description: To make the sign for the letter 'R' in ASL, start with your dominant hand and make a fist. Extend your pinky, ring, and thumb, while keeping your index and middle fingers curled into your palm. The orientation of your hand should be with your palm facing towards you or slightly towards the right if you're right-handed. The movement involves bending your wrist so that your extended fingers move slightly downwards, then return to the starting position, but for the letter 'R', the focus is more on the handshape and less on movement. The fingers that are extended should be straight and relaxed. Your pinky and ring fingers should be next to each other and your thumb should be on the side of your hand, not in front of your fingers. This specific handshape represents the letter 'R' in ASL.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 19. Evaluating sign: S
#   Generated Description: To make the sign for the letter 'S' in ASL, start by holding your dominant hand up with your palm facing inward, toward your body. Make a fist by curling all four fingers - index, middle, ring, and pinky - down toward your palm, so they touch or almost touch it. Your thumb should be on the outside of your fist, positioned on top of your fingers or slightly to the side, but not curled in. Keep your wrist and forearm relaxed. There is little to no movement in this sign; simply hold the fist in place.
#   Faithfulness: 0
#   Answer Relevance: 0.5
#   Context Relevance: 0.5
#
# 20. Evaluating sign: T
#   Generated Description: To make the sign for the letter 'T' in ASL, start by holding your dominant hand up with your palm facing inward, towards your body. Make a fist with your hand, but extend your thumb so it's on top of your index finger, or slightly extended out to the side. Your other fingers - the middle, ring, and pinky - should be curled into your palm. The tip of your thumb should be touching or close to the tip of your index finger. Now, move your hand so your thumb and index finger are pointing upwards, with your wrist straight. Keep your arm relatively straight and your elbow slightly bent. With this handshape, orientation, and position, you have made the ASL sign for the letter 'T'.
#   Faithfulness: 0
#   Answer Relevance: 0.5
#   Context Relevance: 0
#
# 21. Evaluating sign: U
#   Generated Description: To make the sign for the letter 'U' in ASL, start by holding your dominant hand up with your palm facing forward. Make a fist with your hand, but keep your pinky and thumb extended. The pinky should be on the side of your hand, and your thumb should be on top of your hand, but slightly extended outward. Your index, middle, and ring fingers should be curled into your palm, making a fist shape with those three fingers. The pinky and thumb should be in a straight line, parallel to each other. Once you have this handshape, simply hold it in place, with no movement needed. This is the sign for the letter 'U' in ASL.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 22. Evaluating sign: V
#   Generated Description: To make the sign for the letter 'V', start by holding up your dominant hand with your palm facing outward. Make a fist with your hand, but extend your index and middle fingers straight up while keeping the rest of your fingers curled in. The index and middle fingers should be together and parallel to each other, forming a 'V' shape. Your thumb should be tucked into your palm, and your ring and pinky fingers should be curled into your palm as well. Now, hold this handshape steady without moving your hand, and that is the ASL sign for the letter 'V'.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 23. Evaluating sign: W
#   Generated Description: To make the sign for the letter 'W' in ASL, start by holding your dominant hand up with your palm facing forward. Make a fist with your hand, but extend your pinky, ring, and thumb, keeping them straight. Your index and middle fingers should be curled into your palm, touching your thumb. The orientation of your hand should be with your thumb pointing upwards and your pinky and ring fingers pointing downwards. Now, move your hand slightly to the right and then back to the center, but keep your fingers and thumb in the same position. The movement is small and subtle, and your focus should be on keeping the correct handshape.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 24. Evaluating sign: X
#   Generated Description: To perform the ASL sign for the letter 'X', start by holding your dominant hand up with your palm facing forward. Make an 'X' shape with your index and middle fingers by crossing them over each other, while keeping your thumb, ring, and pinky fingers tucked into your palm. Your index and middle fingers should be straight and rigid, with the tip of your index finger resting on top of the middle finger, forming the 'X' shape. Keeping this handshape, move your hand slightly to the right and then back to the left, creating a small crossing motion. This movement helps to emphasize the 'X' shape. Hold the handshape and movement steady and clear, and that's the ASL sign for the letter 'X'.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 25. Evaluating sign: Y
#   Generated Description: To make the sign for the letter 'Y' in ASL, start with your dominant hand and hold it out in front of you. Make a fist with all your fingers except for your pinky and thumb; these two fingers should be extended out to the sides. Your pinky should be straight and pointing out to the side, and your thumb should be pointing up. The orientation of your hand is important: your palm should face inward, toward your body. Now, move your hand so that your wrist is straight and your forearm is parallel to the ground. With this handshape, orientation, and position, you have formed the ASL sign for the letter 'Y'.
#   Faithfulness: 0.5
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 26. Evaluating sign: Z
#   Generated Description: To make the sign for the letter 'Z', start with your dominant hand and make a fist with all fingers curled in towards your palm, but keep your thumb on the outside of your fist, on top of your fingers. The orientation of your hand should be with your palm facing towards you. Move your hand up and then to the side, making a zig-zag motion, first up and then diagonally to the side, as if you're drawing the letter 'Z' in the air. Keep your wrist and forearm still, and only move your hand and fingers. The movement should be smooth and controlled.
#   Faithfulness: 0.5
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# Average Scores:
# Faithfulness: 0.19
# Answer Relevance: 0.38
# Context Relevance: 0.25

# %%
# Plot
labels = ["Faithfulness", "Answer Relevance", "Context Relevance"]
values = [faithfulness_avg, relevance_avg, context_avg]

_, ax = plt.subplots()
ax.bar(labels, values)
ax.set_ylim(0, 1)
ax.set_ylabel("Average Score")
ax.set_xlabel("Evaluation Metric")
ax.set_title("ASL Evaluation Scores")
plt.show()

# %%
import pandas as pd
import json, re
import matplotlib.pyplot as plt
from ibm_watsonx_ai import Credentials, APIClient
from ibm_watsonx_ai.foundation_models import ModelInference
from ibm_watsonx_ai.foundation_models.schema import TextGenParameters
from decouple import Config, RepositoryEnv

# %%
# Load the environment variables using python-decouple
# The .env file should be in the root of the project
# The .env file should NOT be committed to the repository

config = Config(RepositoryEnv(".env.paul"))

# Load the credentials
WX_API_KEY = config("WX_API_KEY")

# %%
credentials = Credentials(
    url = "https://us-south.ml.cloud.ibm.com",
    api_key = WX_API_KEY
)
client = APIClient(
    credentials=credentials, 
    project_id="68126b74-155e-4a70-aa2c-1781dfad87f6"
)

# %%
# --- Setup the Model ---
params = TextGenParameters(
    temperature=0.05,           # Light creativity
    max_new_tokens=300          # Enough for descriptive text
)

model = ModelInference(
    api_client=client,
    params=params,
    model_id="meta-llama/llama-4-scout-17b-16e-instruct",
)

# %%
Sign_knowledge = {
    "A": "Thumb: Curled alongside the side of the index finger, resting against it. Index: Bent downward into the palm, creating a firm curve. Middle: Bent downward in line with the index. Ring: Bent downward. Pinky: Bent downward. Palm Orientation: Facing forward (away from your body). Wrist/Forearm: Neutral position; elbow bent naturally. Movement: None. Note: Represents the shape of a capital 'A'.",
    "B": "Thumb: Folded tightly across the center of the palm, held flat. Index: Extended straight up and held close to the middle finger. Middle: Extended straight up next to the index finger. Ring: Extended straight up next to the middle finger. Pinky: Extended straight up, close to the ring finger. Palm Orientation: Facing forward. Wrist/Forearm: Upright, fingers vertical. Movement: None. Note: Resembles the vertical line of the letter 'B'.",
    "C": "Thumb: Curved naturally to oppose the fingers and help form a half-circle. Index: Curved downward and to the side to help form the top of the 'C'. Middle: Curved to follow the shape created by the index. Ring: Curved in alignment with the rest to form the side of the 'C'. Pinky: Curved slightly to close the 'C' shape. Palm Orientation: Slightly angled outward (to mimic letter curvature). Wrist/Forearm: Slight bend at wrist to angle the 'C'. Movement: None. Note: Entire hand forms a visible capital letter 'C'.",
    "D": "Thumb: Pads rest against the tips of the middle, ring, and pinky fingers. Index: Fully extended upward and isolated from other fingers. Middle: Curved downward to meet the thumb. Ring: Curved downward to meet the thumb. Pinky: Curved downward to meet the thumb. Palm Orientation: Facing forward. Wrist/Forearm: Neutral vertical. Movement: None. Note: Mimics the shape of a capital 'D' with the index as the upright line.",
    "E": "Thumb: Pressed against the palm and touching curled fingers from below. Index: Curled downward toward the palm to meet the thumb. Middle: Curled downward toward the palm. Ring: Curled downward toward the palm. Pinky: Curled downward toward the palm. Palm Orientation: Facing forward. Wrist: Neutral or slightly rotated outward. Movement: None. Note: Shape resembles the loop and middle bar of the letter 'E'.",
    "F": "Thumb: Touches tip of the index finger to form a closed circle. Index: Touches the thumb to complete the circle. Middle: Extended straight up and relaxed, slightly separated. Ring: Extended straight up and relaxed, slightly separated. Pinky: Extended straight up and relaxed, slightly separated. Palm Orientation: Facing forward. Wrist: Neutral to slightly outward. Movement: None. Note: The circle represents the opening in the letter 'F'.",
    "G": "Thumb: Extended sideways, parallel to index. Index: Extended sideways, forming a flat, straight line with thumb. Middle: Folded inward against the palm. Ring: Folded inward against the palm. Pinky: Folded inward against the palm. Palm Orientation: Inward (side of hand faces viewer). Wrist: Horizontal; hand like a gun shape. Movement: None. Note: Emulates the lower stroke of a 'G'.",
    "H": "Thumb: Tucked over curled ring and pinky. Index: Extended to the side. Middle: Extended to the side, beside index. Ring: Curled tightly in palm. Pinky: Curled tightly in palm. Palm Orientation: Facing down or slightly out. Wrist: Flat or slightly turned. Movement: None. Note: Represents two parallel lines, like a sideways 'H'.",
    "I": "Thumb: Folded across or tucked alongside curled fingers. Index: Curled into the palm. Middle: Curled into the palm. Ring: Curled into the palm. Pinky: Extended straight up. Palm Orientation: Facing forward. Wrist: Neutral vertical. Movement: None. Note: Pinky alone resembles a lowercase 'i'.",
    "J": "Thumb: Folded against curled fingers. Index: Curled into the palm. Middle: Curled into the palm. Ring: Curled into the palm. Pinky: Extended and used to trace a 'J' in the air. Palm Orientation: Starts forward, rotates slightly. Movement: Trace 'J' downward, left, then up. Note: Motion is essential to identify this as 'J'.",
    "K": "Thumb: Between index and middle fingers, touching base of middle. Index: Extended diagonally upward. Middle: Extended diagonally upward, apart from index. Ring: Curled into palm. Pinky: Curled into palm. Palm Orientation: Facing out or slightly angled. Wrist: Upright or angled. Movement: None. Note: Mimics the open shape of the letter 'K'.",
    "L": "Thumb: Extended horizontally. Index: Extended vertically. Middle: Curled into palm. Ring: Curled into palm. Pinky: Curled into palm. Palm Orientation: Facing forward. Wrist: Upright. Movement: None. Note: Clearly forms a visual 'L'.",
    "M": "Thumb: Tucked under index, middle, and ring fingers. Index: Folded over the thumb. Middle: Folded over the thumb. Ring: Folded over the thumb. Pinky: Curled beside ring or relaxed. Palm Orientation: Facing out. Wrist: Neutral. Movement: None. Note: Three fingers over thumb = 3 strokes = 'M'.",
    "N": "Thumb: Tucked under index and middle fingers. Index: Folded over thumb. Middle: Folded over thumb. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing out. Movement: None. Note: Two fingers over thumb = 2 strokes = 'N'.",
    "O": "Thumb: Curved inward to meet fingertips. Index: Curved downward to meet thumb. Middle: Curved downward to meet thumb. Ring: Curved downward to meet thumb. Pinky: Curved downward to meet thumb. Palm Orientation: Facing forward. Wrist: Upright or slightly turned. Movement: None. Note: Clear circular 'O' shape.",
    "P": "Thumb: Between and touching middle finger. Index: Extended downward and slightly angled. Middle: Extended and separated from index. Ring: Folded into the palm. Pinky: Folded into the palm. Palm Orientation: Tilted downward. Wrist: Bent downward. Movement: None. Note: Downward angle distinguishes from K.",
    "Q": "Thumb: Parallel to index. Index: Points downward. Middle: Curled into palm. Ring: Curled into palm. Pinky: Curled into palm. Palm Orientation: Downward. Wrist: Bent downward. Movement: None. Note: Like G but rotated to point down.",
    "R": "Thumb: Resting against curled fingers. Index: Crossed over middle finger tightly. Middle: Crossed under index. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Finger crossing symbolizes 'R'.",
    "S": "Thumb: Crossed tightly over the front of curled fingers. Index: Curled into a fist. Middle: Curled into a fist. Ring: Curled into a fist. Pinky: Curled into a fist. Palm Orientation: Facing forward. Wrist: Upright. Movement: None. Note: Fist shape resembles bold 'S'.",
    "T": "Thumb: Inserted between index and middle fingers. Index: Curled downward over the thumb. Middle: Curled downward over the thumb. Ring: Curled into the palm. Pinky: Curled into the palm. Palm Orientation: Facing forward. Movement: None. Note: Thumb poking between fingers resembles old-style 'T'.",
    "U": "Thumb: Folded against palm. Index: Extended straight upward. Middle: Extended straight upward, held together with index. Ring: Folded into the palm. Pinky: Folded into the palm. Palm Orientation: Facing forward. Movement: None. Note: Two fingers = 2 strokes of 'U'.",
    "V": "Thumb: Folded in or at side. Index: Extended upward. Middle: Extended upward, spread apart from index. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Clear 'V' shape.",
    "W": "Thumb: Tucked or relaxed. Index: Extended upward. Middle: Extended upward. Ring: Extended upward, spread slightly. Pinky: Folded into the palm. Palm Orientation: Facing forward. Movement: None. Note: Three fingers = 'W'.",
    "X": "Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'.",
    "Y": "Thumb: Extended sideways. Index: Folded into palm. Middle: Folded into palm. Ring: Folded into palm. Pinky: Extended in opposite direction from thumb. Palm Orientation: Facing forward. Movement: None. Note: Thumb and pinky spread = 'Y' shape.",
    "Z": "Thumb: Folded against curled fingers or at the side. Index: Extended and used to draw a 'Z' in the air. Middle: Curled into palm. Ring: Curled into palm. Pinky: Curled into palm. Palm Orientation: Faces slightly forward, rotating with the movement. Movement: Trace 'Z' in air from top-left to bottom-right."
}

# %%
def create_prompt(sign_name: str) -> str:

    sign_details = Sign_knowledge.get(sign_name.upper(), "Sign not found.")

    return (
        f"You are an American Sign Language (ASL) teacher.\n\n"
        f"Please clearly explain how to perform the ASL sign on a beginner level for the letter '{sign_name}'. "
        f"Use simple language and full sentences. Do not assume any prior knowledge about ASL.\n\n"
        f"Here is relevant information for the letter '{sign_name}':\n"
        f"{sign_details}\n\n"
        f"If you cant generate a description based on the relevant information, output:  'Sorry, I cant help your with this sign' \n\n"
    )

# %%
# --- Generate ASL Description ---
def generate_asl_description(sign_name: str) -> str:
    prompt = create_prompt(sign_name)
    
    response = model.generate(prompt=prompt)
    generated_text = response['results'][0]['generated_text']
    
    return generated_text

# %% [markdown]
# Judge

# %%
# Separate model instance for evaluation (judge), we are always using llama-3-3-70b-instruct based on literature review
params = TextGenParameters(
    temperature=0.01,
    max_new_tokens=100,
)


judge_model = ModelInference(
    api_client=client,
    params=params, 
    model_id="meta-llama/llama-3-3-70b-instruct",
)

# %% [markdown]
# Mass evaluation

# %%
def create_comparison_judge_prompt(sign_name: str, generated_description: str, expected_description: str, guardrails="json") -> str:
    return f"""You are evaluating the quality of a generated ASL sign description based on 3 criteria by comparing it to a ground truth.

Sign: "{sign_name}"

Expected (ground truth) description:
"{expected_description}"

Generated description:
"{generated_description}"

The criteria are:
1. Faithfulness: The content of the generated description can be interfered from the content of the ground truth.
2. Answer Relevance: The generated description specifically and sufficiently describes the requested sign.
3. Context Relevance: The generated description exclusively contains information that is needed to describe the sign.

Grade each criterion from 0 to 1:
- 1 - The generated description fully meets the criterion
- 0.5 - The generated description partially meets the criterion
- 0 - The generated description does not meet the criterion

Do not downgrade the generated description for variation in wording or style. 

Here are a few examples of how to answer:
- example 1:
  - expected description "Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."
  - generated description "To sign the letter X in American Sign Language (ASL), make a fist with your dominant hand. Extend your index finger and bend only the tip forward to form a small hook. Face your palm forward so the hooked index finger is visible"
  - response: "faithfulness": 1, "answer_relevance": 1, "context_relevance": 1
- example 2:
  - expected description "Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."
  - generated description "Dance in a circle like you never danced before."
  - response: "faithfulness": 0, "answer_relevance": 0, "context_relevance": 0
- example 3:
  - expected description "Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."
  - generated description "To sign the letter X in American Sign Language (ASL), make a fist with your dominant hand. Extend your index finger and bend only the tip forward to form a small hook."
  - response: "faithfulness": 1, "answer_relevance": 1, "context_relevance": 1
- example 4:
  - expected description "Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."
  - generated description "Hello user, this is a great question. I also love to make the sign for the letter 'X'. To sign the letter X in American Sign Language (ASL), make a fist with your dominant hand. Extend your index finger and bend only the tip forward to form a small hook."
  - response: "faithfulness": 0.5, "answer_relevance": 1, "context_relevance": 0.5
- example 5:
  - expected description Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."
  - generated description "To sign the letter X in American Sign Language (ASL), make a fist with your dominant hand and extend your index finger"
  - response: "faithfulness": 1, "answer_relevance": 0.5, "context_relevance": 1
- example 6:
  - expected description "Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."
  - generated description "To sign the letter X in American Sign Language (ASL), make a fist with your dominant hand. Extend your index finger and bend only the tip forward to form a small hook. Keep your thumb resting against the side of your curled middle finger. The middle, ring, and pinky fingers stay curled into the palm. There is no movement; the hand remains still"
  - response: "faithfulness": 1, "answer_relevance": 1, "context_relevance": 0.5

Think carefully for each criterion before answering.

Respond only in the following format, enclosed within <output> tags:

<output>
{{
  "faithfulness": <0, 0.5, or 1>,
  "answer_relevance": <0, 0.5, or 1>,
  "context_relevance": <0, 0.5, or 1>
}}
</output>
"""

# %%
def evaluate_against_ground_truth(sign_name: str, generated_description: str, expected_description: str) -> dict:
    prompt = create_comparison_judge_prompt(sign_name, generated_description, expected_description)

    def try_parse_response(response_text: str) -> dict:
        result = {
            "faithfulness": None,
            "answer_relevance": None,
            "context_relevance": None
        }

        # Try direct parse
        try:
            # Strip leading text if any
            json_start = response_text.find("{")
            if json_start != -1:
                response_text = response_text[json_start:]

            parsed = json.loads(response_text)
            if isinstance(parsed, dict):
                result.update(parsed)
                return result
        except Exception:
            pass

        # Try fallback regex
        matches = re.findall(r"\{.*?\}", response_text, re.DOTALL)
        for match in matches:
            try:
                parsed = json.loads(match)
                if isinstance(parsed, dict):
                    result.update(parsed)
                    return result
            except Exception as e:
                continue

        return result  # fallback with None values if all fails

    # First attempt
    response = judge_model.generate(prompt=prompt)
    judged_text = response['results'][0]['generated_text']
    result = try_parse_response(judged_text)

    # Retry once if parsing failed
    if any(v is None for v in result.values()):
        print(f" First parse failed for sign '{sign_name}', retrying once...")
        response_retry = judge_model.generate(prompt=prompt)
        judged_text_retry = response_retry['results'][0]['generated_text']
        result = try_parse_response(judged_text_retry)

    # Final message if still failing
    if any(v is None for v in result.values()):
        print(f" Failed to parse JSON after retry for sign: '{sign_name}'.")

    return result

# %%
#Testing judge with manual input
sign = "hello"
expected = "Begin with the side of your index finger against your forehead and then move your hand up and away from your head."
generated = "Start with the side of your index touching your forehead, then extend your pinky"

scores = evaluate_against_ground_truth(sign, generated, expected)

print("\nJudge Result:")
print(f"Faithfulness: {scores['faithfulness']}")
print(f"Answer Relevance: {scores['answer_relevance']}")
print(f"Context Relevance: {scores['context_relevance']}")
# Out:
# Judge Result:
# Faithfulness: 0.5
# Answer Relevance: 0.5
# Context Relevance: 0.5

# %%
test_data = [
    {"sign": "A", "expected": "Thumb: Curled alongside the side of the index finger, resting against it. Index: Bent downward into the palm, creating a firm curve. Middle: Bent downward in line with the index. Ring: Bent downward. Pinky: Bent downward. Palm Orientation: Facing forward (away from your body). Wrist/Forearm: Neutral position; elbow bent naturally. Movement: None. Note: Represents the shape of a capital 'A'."},
    {"sign": "B", "expected": "Thumb: Folded tightly across the center of the palm, held flat. Index: Extended straight up and held close to the middle finger. Middle: Extended straight up next to the index finger. Ring: Extended straight up next to the middle finger. Pinky: Extended straight up, close to the ring finger. Palm Orientation: Facing forward. Wrist/Forearm: Upright, fingers vertical. Movement: None. Note: Resembles the vertical line of the letter 'B'."},
    {"sign": "C", "expected": "Thumb: Curved naturally to oppose the fingers and help form a half-circle. Index: Curved downward and to the side to help form the top of the 'C'. Middle: Curved to follow the shape created by the index. Ring: Curved in alignment with the rest to form the side of the 'C'. Pinky: Curved slightly to close the 'C' shape. Palm Orientation: Slightly angled outward (to mimic letter curvature). Wrist/Forearm: Slight bend at wrist to angle the 'C'. Movement: None. Note: Entire hand forms a visible capital letter 'C'."},
    {"sign": "D", "expected": "Thumb: Pads rest against the tips of the middle, ring, and pinky fingers. Index: Fully extended upward and isolated from other fingers. Middle: Curved downward to meet the thumb. Ring: Curved downward to meet the thumb. Pinky: Curved downward to meet the thumb. Palm Orientation: Facing forward. Wrist/Forearm: Neutral vertical. Movement: None. Note: Mimics the shape of a capital 'D' with the index as the upright line."},
    {"sign": "E", "expected": "Thumb: Pressed against the palm and touching curled fingers from below. Index: Curled downward toward the palm to meet the thumb. Middle: Curled downward toward the palm. Ring: Curled downward toward the palm. Pinky: Curled downward toward the palm. Palm Orientation: Facing forward. Wrist: Neutral or slightly rotated outward. Movement: None. Note: Shape resembles the loop and middle bar of the letter 'E'."},
    {"sign": "F", "expected": "Thumb: Touches tip of the index finger to form a closed circle. Index: Touches the thumb to complete the circle. Middle: Extended straight up and relaxed, slightly separated. Ring: Extended straight up and relaxed, slightly separated. Pinky: Extended straight up and relaxed, slightly separated. Palm Orientation: Facing forward. Wrist: Neutral to slightly outward. Movement: None. Note: The circle represents the opening in the letter 'F'."},
    {"sign": "G", "expected": "Thumb: Extended sideways, parallel to index. Index: Extended sideways, forming a flat, straight line with thumb. Middle: Folded inward against the palm. Ring: Folded inward against the palm. Pinky: Folded inward against the palm. Palm Orientation: Inward (side of hand faces viewer). Wrist: Horizontal; hand like a gun shape. Movement: None. Note: Emulates the lower stroke of a 'G'."},
    {"sign": "H", "expected": "Thumb: Tucked over curled ring and pinky. Index: Extended to the side. Middle: Extended to the side, beside index. Ring: Curled tightly in palm. Pinky: Curled tightly in palm. Palm Orientation: Facing down or slightly out. Wrist: Flat or slightly turned. Movement: None. Note: Represents two parallel lines, like a sideways 'H'."},
    {"sign": "I", "expected": "Thumb: Folded across or tucked alongside curled fingers. Index: Curled into the palm. Middle: Curled into the palm. Ring: Curled into the palm. Pinky: Extended straight up. Palm Orientation: Facing forward. Wrist: Neutral vertical. Movement: None. Note: Pinky alone resembles a lowercase 'i'."},
    {"sign": "J", "expected": "Thumb: Folded against curled fingers. Index: Curled into the palm. Middle: Curled into the palm. Ring: Curled into the palm. Pinky: Extended and used to trace a 'J' in the air. Palm Orientation: Starts forward, rotates slightly. Movement: Trace 'J' downward, left, then up. Note: Motion is essential to identify this as 'J'."},
    {"sign": "K", "expected": "Thumb: Between index and middle fingers, touching base of middle. Index: Extended diagonally upward. Middle: Extended diagonally upward, apart from index. Ring: Curled into palm. Pinky: Curled into palm. Palm Orientation: Facing out or slightly angled. Wrist: Upright or angled. Movement: None. Note: Mimics the open shape of the letter 'K'."},
    {"sign": "L", "expected": "Thumb: Extended horizontally. Index: Extended vertically. Middle: Curled into palm. Ring: Curled into palm. Pinky: Curled into palm. Palm Orientation: Facing forward. Wrist: Upright. Movement: None. Note: Clearly forms a visual 'L'."},
    {"sign": "M", "expected": "Thumb: Tucked under index, middle, and ring fingers. Index: Folded over the thumb. Middle: Folded over the thumb. Ring: Folded over the thumb. Pinky: Curled beside ring or relaxed. Palm Orientation: Facing out. Wrist: Neutral. Movement: None. Note: Three fingers over thumb = 3 strokes = 'M'."},
    {"sign": "N", "expected": "Thumb: Tucked under index and middle fingers. Index: Folded over thumb. Middle: Folded over thumb. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing out. Movement: None. Note: Two fingers over thumb = 2 strokes = 'N'."},
    {"sign": "O", "expected": "Thumb: Curved inward to meet fingertips. Index: Curved downward to meet thumb. Middle: Curved downward to meet thumb. Ring: Curved downward to meet thumb. Pinky: Curved downward to meet thumb. Palm Orientation: Facing forward. Wrist: Upright or slightly turned. Movement: None. Note: Clear circular 'O' shape."},
    {"sign": "P", "expected": "Thumb: Between and touching middle finger. Index: Extended downward and slightly angled. Middle: Extended and separated from index. Ring: Folded into the palm. Pinky: Folded into the palm. Palm Orientation: Tilted downward. Wrist: Bent downward. Movement: None. Note: Downward angle distinguishes from K."},
    {"sign": "Q", "expected": "Thumb: Parallel to index. Index: Points downward. Middle: Curled into palm. Ring: Curled into palm. Pinky: Curled into palm. Palm Orientation: Downward. Wrist: Bent downward. Movement: None. Note: Like G but rotated to point down."},
    {"sign": "R", "expected": "Thumb: Resting against curled fingers. Index: Crossed over middle finger tightly. Middle: Crossed under index. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Finger crossing symbolizes 'R'."},
    {"sign": "S", "expected": "Thumb: Crossed tightly over the front of curled fingers. Index: Curled into a fist. Middle: Curled into a fist. Ring: Curled into a fist. Pinky: Curled into a fist. Palm Orientation: Facing forward. Wrist: Upright. Movement: None. Note: Fist shape resembles bold 'S'."},
    {"sign": "T", "expected": "Thumb: Inserted between index and middle fingers. Index: Curled downward over the thumb. Middle: Curled downward over the thumb. Ring: Curled into the palm. Pinky: Curled into the palm. Palm Orientation: Facing forward. Movement: None. Note: Thumb poking between fingers resembles old-style 'T'."},
    {"sign": "U", "expected": "Thumb: Folded against palm. Index: Extended straight upward. Middle: Extended straight upward, held together with index. Ring: Folded into the palm. Pinky: Folded into the palm. Palm Orientation: Facing forward. Movement: None. Note: Two fingers = 2 strokes of 'U'."},
    {"sign": "V", "expected": "Thumb: Folded in or at side. Index: Extended upward. Middle: Extended upward, spread apart from index. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Clear 'V' shape."},
    {"sign": "W", "expected": "Thumb: Tucked or relaxed. Index: Extended upward. Middle: Extended upward. Ring: Extended upward, spread slightly. Pinky: Folded into the palm. Palm Orientation: Facing forward. Movement: None. Note: Three fingers = 'W'."},
    {"sign": "X", "expected": "Thumb: Resting at side or across curled fingers. Index: Bent to form a hook. Middle: Folded into palm. Ring: Folded into palm. Pinky: Folded into palm. Palm Orientation: Facing forward. Movement: None. Note: Hooked finger mimics 'X'."},
    {"sign": "Y", "expected": "Thumb: Extended sideways. Index: Folded into palm. Middle: Folded into palm. Ring: Folded into palm. Pinky: Extended in opposite direction from thumb. Palm Orientation: Facing forward. Movement: None. Note: Thumb and pinky spread = 'Y' shape."},
    {"sign": "Z", "expected": "Thumb: Folded against curled fingers or at the side. Index: Extended and used to draw a 'Z' in the air. Middle: Curled into palm. Ring: Curled into palm. Pinky: Curled into palm. Palm Orientation: Faces slightly forward, rotating with the movement. Movement: Trace 'Z' in air from top-left to bottom-right."}
]

# %%
# Store all scores
all_scores = []

# Counter to indicate progress of the evaluation
i = 0

for entry in test_data:
    i += 1
    print(f"\n{i}. Evaluating sign: {entry['sign']}")
    sign = entry["sign"]
    expected = entry["expected"]

    # Generate from LLM
    generated = generate_asl_description(sign)

    # Print the generated description
    print(f"  Generated Description: {generated}")

    # Judge against expected
    scores = evaluate_against_ground_truth(sign, generated, expected)
    all_scores.append(scores)

    # Print individual scores
    print(f"  Faithfulness: {scores['faithfulness']}")
    print(f"  Answer Relevance: {scores['answer_relevance']}")
    print(f"  Context Relevance: {scores['context_relevance']}")

# Compute and print average for each metric
print("\nAverage Scores:")
faithfulness_avg = sum(s["faithfulness"] for s in all_scores if s["faithfulness"] is not None) / len(all_scores)
print(f"Faithfulness: {faithfulness_avg:.2f}")
relevance_avg = sum(s["answer_relevance"] for s in all_scores if s["answer_relevance"] is not None) / len(all_scores)
print(f"Answer Relevance: {relevance_avg:.2f}")
context_avg = sum(s["context_relevance"] for s in all_scores if s["context_relevance"] is not None) / len(all_scores)
print(f"Context Relevance: {context_avg:.2f}")
# Out:
# 1. Evaluating sign: A
#   Generated Description: Here to help you learn American Sign Language! I'd be happy to teach you the ASL sign for the letter 'A'.
#
# To perform the ASL sign for the letter 'A', start by holding your dominant hand in front of you with your palm facing forward, away from your body.
#
# Next, bend your index finger downward into your palm, making a firm curve with the finger.
#
# Then, bring your thumb alongside your index finger and curl it so that it rests against the side of your index finger.
#
# After that, bend your middle, ring, and pinky fingers downward, keeping them in line with your index finger.
#
# Make sure to keep your wrist and forearm in a neutral position, with your elbow bent naturally.
#
# The key to this sign is to keep your hand still and not move it; there should be no movement.
#
# By following these steps, you should be able to form the ASL sign for the letter 'A', which represents the shape of a capital 'A'.
#
# Practice makes perfect, so try signing the letter 'A' several times to get a feel for it!
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 2. Evaluating sign: B
#   Generated Description: Here to help you learn American Sign Language! I'd be happy to teach you the ASL sign for the letter 'B'.
#
# To sign the letter 'B' in ASL, you will start by making a fist with your hand but not a tight fist.
# Instead, you will keep your thumb folded tightly across the center of your palm, making sure it is flat against your palm.
#
# Next, you will extend your index finger straight up, keeping it close to your middle finger.
# Then, you will also extend your middle finger straight up, right next to your index finger.
# Your ring finger and pinky finger should also be extended straight up, with the ring finger next to the middle finger and the pinky finger close to the ring finger.
#
# It's essential to keep your palm facing forward and your wrist and forearm upright, with your fingers held vertically.
# The key to this sign is to keep all your fingers straight and your hand steady, with no movement.
# When you put it all together, your handshape should resemble the vertical line of the letter 'B'.
#
# Practice makes perfect, so try signing the letter 'B' several times to get a feel for it.
# Remember to keep your thumb flat against your palm, your fingers straight and close together, and your hand steady.
#
# With a little practice, you'll be signing the letter 'B' like a pro!
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 3. Evaluating sign: C
#   Generated Description: Hereassistant<|header_end|>
#
# To sign the letter 'C' in American Sign Language (ASL), start by holding your hand out in front of you.
#
# Next, gently curve your thumb towards your fingers so that it can help form a half-circle shape with your other fingers.
#
# Now, curve your index finger downward and to the side, making sure it's not straight but rather forming the top part of a 'C' shape.
#
# Your middle finger should also be curved, following the shape that your index finger has made, to help create a smooth curve for the letter 'C'.
#
# The ring finger should be curved as well, aligning with the rest of your fingers to form the side of the 'C'.
#
# Your pinky finger should be slightly curved to help close the 'C' shape, making sure it's not sticking out but rather completing the circle.
#
# As for your palm, turn it so that it's slightly angled outward. This helps mimic the curvature of the letter 'C'.
#
# At your wrist and forearm, make a slight bend. This will help angle your hand in a way that the 'C' shape is visible and clear.
#
# Remember, when you've formed the 'C' shape with your hand, there should be no movement. The goal is to hold your hand steady in the shape of a capital letter 'C' so that it's easily recognizable.
#
# By following these steps, you should be able to form a clear and correct ASL sign for the letter 'C'.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 4. Evaluating sign: D
#   Generated Description: HereTo sign the letter 'D' in American Sign Language (ASL), you will need to make a specific handshape.
# First, you need to place your thumb so that the pad of your thumb rests against the tips of your middle, ring, and pinky fingers.
# Next, you need to fully extend your index finger upward, making sure it is isolated and not touching the other fingers.
# Then, you need to curve your middle, ring, and pinky fingers downward so that they meet your thumb.
# The palm of your hand should be facing forward, and your wrist and forearm should be in a neutral, vertical position.
# There is no movement required for this sign; you simply hold the handshape.
# The resulting handshape should resemble the shape of a capital letter 'D', with your index finger acting as the upright line.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 5. Evaluating sign: E
#   Generated Description: ## Step 1: Understand the hand configuration for the letter 'E' in ASL.
# To sign the letter 'E' in ASL, you need to start by making a specific hand shape. This involves curling your fingers and positioning your thumb in a particular way.
#
# ## Step 2: Position the thumb.
# The thumb needs to be pressed against the palm of your hand and should touch the curled fingers from below. This means your thumb will be on the underside of your palm, making contact with the tips of your curled fingers.
#
# ## 3: Curl the fingers.
# Curl your index, middle, ring, and pinky fingers downward toward the palm. This curling motion should be such that the tips of these fingers meet or are close to the palm.
#
# ## 4: Orient the palm and wrist.
# The palm of your hand should be facing forward, and your wrist should be in a neutral position or slightly rotated outward. This orientation is important for the correct sign.
#
# ## 5: Complete the sign.
# The sign for 'E' does not require any movement. Once you have achieved the hand configuration described, you simply hold it in place. The shape of your hand should resemble the loop and middle bar of the letter 'E'.
#
# ## 6: Practice the sign.
# To get comfortable with the sign, practice making the hand shape several times. Ensure that your thumb is pressed against your palm, your fingers are curled downward, and your palm is facing forward.
#
#
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 6. Evaluating sign: F
#   Generated Description: Hereassistant<|header_end|>
#
# To perform the ASL sign for the letter 'F', start by making a circle with your thumb and index finger, so that they touch at the tips. Keep your middle, ring, and pinky fingers extended straight up and relaxed, and make sure they are slightly separated from each other. The palm of your hand should be facing forward, and your wrist should be in a neutral or slightly outward position. There is no movement required for this sign, so simply hold your hand in this position. This circle shape formed by your thumb and index finger represents the opening in the letter 'F'.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 7. Evaluating sign: G
#   Generated Description: Here is an example description for the letter 'A':
# To sign the letter 'A' in American Sign Language, start by holding your dominant hand up with your palm facing forward. Extend your thumb and pinky finger, while keeping your index, middle, and ring fingers folded down toward your palm. Keep your wrist straight and your hand relaxed. There is no movement needed for this sign, simply hold your hand in this position.
#   Faithfulness: 0
#   Answer Relevance: 0
#   Context Relevance: 0
#
# 8. Evaluating sign: H
#   Generated Description: Hereassistant<|header_end|>
#
# To sign the letter 'H' in American Sign Language (ASL), start by curling your ring and pinky fingers tightly into your palm. At the same time, tuck your thumb over these curled fingers.
#
# Next, extend your index and middle fingers to the side, keeping them straight and parallel to each other. These two fingers should be beside each other, not crossed, and they represent the two parallel lines of the letter 'H' when viewed from the side.
#
# Make sure your palm is facing downwards or slightly outward, and keep your wrist flat or slightly turned.
#
# The key to this sign is to keep your hand steady and not move it; the sign for 'H' is a static or non-moving sign.
#
# By following these steps, you should be able to form the ASL sign for the letter 'H'. Practice makes perfect, so try signing 'H' several times to get comfortable with the handshape and position.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 9. Evaluating sign: I
#   Generated Description: ## Step 1: Start with the basic hand position
# To begin signing the letter 'I' in American Sign Language (ASL), you need to start with your dominant hand. Make sure your wrist is in a neutral, vertical position.
#
# ## Step 2: Curl the fingers
# Curl your index, middle, and ring fingers into your palm. This means bending them towards your palm so that the tips of these fingers touch your palm.
#
# ## 3: Position the thumb
# Fold your thumb across or tuck it alongside your curled fingers. This helps to keep your thumb out of the way and in contact with the other fingers.
#
# ## 4: Extend the pinky
# Extend your pinky finger straight up. This finger should be the only one standing straight up while the others are curled into the palm.
#
# ## 5: Orient the palm
# Make sure your palm is facing forward. This is an important part of the sign for the letter 'I', as it helps to clearly communicate the letter.
#
# ## 6: Final check
# Double-check that your wrist is still in a neutral, vertical position and that you are not moving your hand. The sign for 'I' in ASL does not involve any movement.
#
# ## 7: Completion
# With your pinky extended straight up and the rest of your fingers curled into your palm, and your thumb folded across or tucked alongside your curled fingers, you are now signing the letter 'I' in ASL. Remember, the
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 10. Evaluating sign: J
#   Generated Description: Here to help you learn American Sign Language! Let's get started with the letter 'J'.
#
# To sign the letter 'J' in ASL, you will need to make a specific handshape with your dominant hand. First, curl your index, middle, and ring fingers into your palm, so they are tucked in. At the same time, keep your pinky finger extended and straight.
#
# Next, fold your thumb against your curled fingers, so it is pressed against them.
#
# Now, orient your palm to face forward, and then slightly rotate it as you make the sign.
#
# The key to signing the letter 'J' is the movement. Slowly move your pinky finger to trace the shape of the letter 'J' in the air. Start by moving your pinky finger downward, then move it to the left, and finally move it up to complete the 'J' shape.
#
# As you practice signing the letter 'J', remember to keep your index, middle, and ring fingers curled into your palm and your thumb folded against them. Your pinky finger should be doing all the movement to create the 'J' shape.
#
# With a little practice, you'll be able to sign the letter 'J' easily and correctly in ASL!
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 11. Evaluating sign: K
#   Generated Description: Hereassistant<|header_end|>
#
# To perform the ASL sign for the letter 'K', start by making a fist with your hand but keep your index and middle fingers extended.
#
# Next, place your thumb so that it touches the base of your middle finger, and position it between your index and middle fingers.
#
# Now, extend your index and middle fingers so that they are pointing diagonally upward and are apart from each other.
#
# Then, curl your ring and pinky fingers into your palm.
#
# The palm of your hand should be facing outward or slightly angled, and your wrist should be held upright or slightly angled.
#
# The handshape should resemble the open shape of the letter 'K', and there should be no movement.
#
# That's it! You've successfully performed the ASL sign for the letter 'K'.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 12. Evaluating sign: L
#   Generated Description: HereTo perform the ASL sign for the letter 'L', you will need to position your hand in a specific way.
#
# First, extend your thumb out to the side, so it is straight and horizontal.
#
# Next, extend your index finger up, so it is straight and vertical.
#
# Then, curl your middle finger, ring finger, and pinky finger down into your palm.
#
# Make sure your palm is facing forward, and keep your wrist straight and upright.
#
# You should see that your thumb and index finger form a clear shape of the letter 'L'.
#
# There is no movement needed for this sign, just hold your hand steady in this position.
#
# By following these steps, you should be able to correctly sign the letter 'L' in ASL.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 13. Evaluating sign: M
#   Generated Description: Hereassistant<|header_end|>
#
# To perform the ASL sign for the letter 'M', start by placing your thumb under your index, middle, and ring fingers. Then, fold your index, middle, and ring fingers over your thumb, so that they are resting on top of it. Your pinky finger can be curled beside your ring finger or relaxed, it doesn't matter which. Make sure your palm is facing outward, and keep your wrist in a neutral position, not bent up or down. You don't need to move your hand at all to make this sign. The key to this sign is that three fingers - your index, middle, and ring fingers - are folded over your thumb, which represents the letter 'M' because it can be thought of as three strokes. By holding your hand in this position, you are signing the letter 'M' in ASL.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 14. Evaluating sign: N
#   Generated Description: ## Step 1: Start with the basic handshape
# To begin signing the letter 'N' in American Sign Language (ASL), you need to form a specific handshape. Start by holding your hand out in front of you with your palm facing outward.
#
# ## Step 2: Position the thumb
# Tuck your thumb under your index and middle fingers. This means you will use your index and middle fingers to hold your thumb in place, making sure it is underneath them.
#
# ## 3: Fold the index and middle fingers over the thumb
# Next, fold your index and middle fingers over your thumb, so they are resting on top of it. This action helps to secure your thumb in its position.
#
# ## 4: Position the ring and pinky fingers
# Fold your ring and pinky fingers into your palm. This means you should curl them inward, toward your palm, so they are not extended.
#
# ## 5: Confirm the palm orientation
# Make sure your palm is facing outward. This is an important part of the sign for the letter 'N'.
#
# ## 6: Understand the movement
# The sign for 'N' does not require any movement. You will hold the handshape in place without moving your hand.
#
# ## 7: Relate to the note about two fingers over the thumb
# The note mentions that two fingers over the thumb equals 2 strokes, which corresponds to the letter 'N'. However, in the context of forming the sign, this note is more
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 15. Evaluating sign: O
#   Generated Description: Here are some examples of descriptions I have seen:
# * To sign the letter 'A', you need to make a fist with your dominant hand and extend your pinky and index finger while keeping your thumb, middle finger, and ring finger curled into your palm.
# * To sign the letter 'B', you extends your thumb, index, and middle fingers while keeping your ring and pinky fingers curled into your palm.
# * To sign the letter 'C', you make a fist with your dominant hand and extend your thumb.
#
# I<|header_start|>assistant<|header_end|>
#
# To sign the letter 'O', you need to make a circular shape with your dominant hand by curling your thumb inward to meet your fingertips. At the same time, curve your index, middle, ring, and pinky fingers downward so that they meet your thumb, forming a complete circle. Keep your palm facing forward and your wrist in an upright or slightly turned position. Hold this shape without moving your hand, making sure to keep a clear and distinct circular 'O' shape.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 16. Evaluating sign: P
#   Generated Description: Here to help you learn ASL! Let's get started with the letter 'P'. To make the ASL sign for the letter 'P', you will need to position your thumb between and touching your middle finger.
#
# Next, extend your index finger downward, but make sure it's slightly angled.
#
# Your middle finger should also be extended, but it should be separated from your index finger.
#
# Now, fold your ring finger and pinky finger into your palm.
#
# The palm of your hand should be tilted downward, and your wrist should be bent downward as well.
#
# The key thing to remember is that there is no movement needed for this sign; you just hold the handshape in place.
#
# By following these steps, you should be able to make the ASL sign for the letter 'P'. The downward angle of your index finger is especially important, as it helps distinguish the sign for 'P' from the sign for 'K'.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 17. Evaluating sign: Q
#   Generated Description: Here are some examples of descriptions I have seen:
# * To sign the letter 'A', you start by making a fist with your hand, but keep your thumb on the outside of your fingers.
# * To sign the letter 'B', you hold up your thumb, index, and middle fingers, and keep your ring and pinky fingers curled into your palm.
# * To sign the letter 'G', you make a fist with your hand and extend your thumb so that it is parallel to your index finger.
#
# Here in lies theassistant<|header_end|>
#
# To sign the letter 'Q' in American Sign Language (ASL), you start by making a fist with your hand. Extend your thumb so that it is parallel to your index finger. Then, point your index finger downward. Next, curl your middle, ring, and pinky fingers into your palm. Make sure your palm is facing downward and your wrist is bent downward, so your hand is positioned with your fingers pointing down. You do not move your hand; you simply hold it in this position. This sign is similar to the sign for the letter 'G', but rotated so that your index finger points downward instead of to the side.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 18. Evaluating sign: R
#   Generated Description: HereTo perform the ASL sign for the letter 'R', you will need to make a specific hand shape.
# First, curl your fingers, making a fist but not a tight one.
# Next, place your thumb against the curled fingers, resting it there.
# Now, cross your index finger over your middle finger, making sure they are tightly together.
# The middle finger will be under the index finger.
# Then, fold your ring and pinky fingers into your palm.
# Keep your palm facing forward, and do not move your hand.
# The crossing of the index and middle fingers is what symbolizes the letter 'R' in ASL.
# By following these steps, you should be able to make the correct hand shape for the letter 'R'.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 19. Evaluating sign: S
#   Generated Description: ## Step 1: Understand the hand configuration for the ASL sign for the letter 'S'.
# To start, make a fist with your hand. This means curling all your fingers - index, middle, ring, and pinky - into your palm.
#
# ## Step 2: Modify the fist to fit the specific requirements for the letter 'S'.
# Cross your thumb tightly over the front of your curled fingers. This will help you achieve the correct shape for the letter 'S', which resembles a bold 'S' when your hand is oriented correctly.
#
# ## 3: Orient the palm and wrist correctly.
# Make sure your palm is facing forward and your wrist is upright. This is crucial for the correct orientation of the sign.
#
# ## 4: Confirm there is no movement.
# The sign for the letter 'S' in ASL does not involve any movement. Once you have your hand in the correct position, hold it still.
#
# ## 5: Combine all elements to perform the ASL sign for 'S'.
# Putting it all together: Make a fist with all fingers curled in, cross your thumb over the front of your curled fingers, keep your palm facing forward, and your wrist upright. Hold this position without moving your hand.
#
# The final answer is: $\boxed{To sign the letter 'S' in ASL, start by making a fist with all your fingers curled into your palm. Then, cross your thumb tightly over the front of your curled fingers. Make sure your palm
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 20. Evaluating sign: T
#   Generated Description: Here to help you learn ASL! Let's get started with the letter 'T'. To make the sign for the letter 'T', you will need to use your dominant hand.
#
# First, make a fist with your hand, but not a tight one. Then, extend your thumb and place it between your index and middle fingers.
#
# Next, curl your index and middle fingers down so that they rest on top of your thumb. Your ring and pinky fingers should be curled into your palm.
#
# The palm of your hand should be facing forward, toward the person you are signing to.
#
# The handshape and fingers should remain in this position, with no movement.
#
# That's it! You are now making the ASL sign for the letter 'T'. Practice makes perfect, so try it a few times to get a feel for it.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 0.5
#
# 21. Evaluating sign: U
#   Generated Description: Here are some general guidelines for describing ASL signs:
# - Describe the handshape, palm orientation, and movement.
# - Use simple sentences.
# - Do make references to physical body parts.
# - Do not assume prior knowledge of ASL.
#
# ## Step 1: Determine the handshape for the letter 'U' in ASL.
# To sign the letter 'U' in ASL, start by making a specific handshape. Place your thumb against the palm of your hand. Extend your index and middle fingers straight up, making sure they are held together. At the same time, fold your ring and pinky fingers into your palm.
#
# ## 2: Describe the palm orientation for the letter 'U'.
# The palm of your hand should be facing forward. This means that the front of your palm is directed towards the person you are communicating with.
#
# ## 3: Explain the movement for the letter 'U'.
# For the letter 'U', there is no movement involved. Your hand should remain still while making the sign.
#
# ## 4: Clarify the note about two fingers and strokes of 'U'.
# The letter 'U' is represented by two fingers (the index and middle fingers) being extended. This can also be thought of as making two strokes of the letter 'U', but in ASL, this is represented statically with the described handshape.
#
# ## 5: Combine the information into a simple instructional guide.
# To sign the letter 'U' in ASL, follow these steps:
# - Make a handshape
#   Faithfulness: 0.5
#   Answer Relevance: 0.5
#   Context Relevance: 0
#
# 22. Evaluating sign: V
#   Generated Description: HereTo perform the ASL sign for the letter 'V', you will need to make a specific hand shape.
# First, fold your thumb into your palm or keep it at the side of your hand.
# Next, extend your index finger straight up.
# Then, extend your middle finger straight up, making sure it is spread apart from your index finger.
# After that, fold your ring finger and pinky finger into your palm.
# The palm of your hand should be facing forward.
# There should be no movement in your hand; it should be still.
# When you put your hand in this position, you should see a clear 'V' shape formed by your index and middle fingers.
# That's the ASL sign for the letter 'V'!
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 23. Evaluating sign: W
#   Generated Description: ## Step 1: Start with the basic handshape
# To begin, make sure your hand is relaxed. You will need to extend your index, middle, and ring fingers upward, while keeping your pinky finger folded into your palm.
#
# ## Step 2: Position your thumb
# Your thumb should either be tucked in or relaxed, not extended or playing a role in the sign.
#
# ## 3: Extend and spread the fingers
# Extend your index, middle, and ring fingers straight up. Make sure your ring finger is spread slightly away from the other two extended fingers.
#
# ## 4: Orient your palm
# Position your hand so that your palm is facing forward. This is crucial for the correct orientation of the sign.
#
# ## 5: Finalize the sign
# There is no movement required for the letter 'W' in ASL. Simply hold your hand in the described position with your index, middle, and ring fingers extended upward, your pinky folded into your palm, and your thumb either tucked or relaxed.
#
# ## 6: Confirm the sign
# The sign for 'W' is confirmed when you have three fingers extended (index, middle, and ring), your pinky is folded in, your thumb is not actively involved, and your palm is facing forward.
#
# The final answer is: $\boxed{W}$
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 24. Evaluating sign: X
#   Generated Description: Hereassistant<|header_end|>
#
# To perform the ASL sign for the letter 'X', start by curling your middle, ring, and pinky fingers into your palm. Next, bend your index finger to form a hook shape, keeping it separate from the other fingers. Place your thumb either at the side of your hand or across your curled fingers for support. Make sure your palm is facing forward. You should see the hooked shape of your index finger, which mimics the shape of the letter 'X'. Hold this position and do not move your hand; the sign for 'X' is a static sign, meaning it doesn't require any movement. By following these steps, you will be able to correctly sign the letter 'X' in American Sign Language.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 25. Evaluating sign: Y
#   Generated Description: HereTo perform the ASL sign for the letter 'Y', you will need to position your hand in a specific way.
#
# First, extend your thumb sideways, which means you will move it away from your palm and keep it straight.
#
# Next, fold your index finger into your palm, which means you will bend it down and touch the pad of your finger to your palm.
#
# You will do the same with your middle finger and your ring finger; fold them into your palm.
#
# Now, extend your pinky finger in the opposite direction from your thumb, which means it will be on the other side of your hand and also straight.
#
# The palm of your hand should be facing forward, directly towards the person you are signing to.
#
# There should be no movement in your hand; keep it still.
#
# The key to this sign is that your thumb and pinky finger should be spread apart, creating the shape of the letter 'Y'.
#
# By following these steps, you will be able to correctly sign the letter 'Y' in American Sign Language.
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# 26. Evaluating sign: Z
#   Generated Description: ## Step 1: Understand the hand configuration for the ASL sign for 'Z'.
# To start, you need to configure your hand properly. This means folding your thumb against your curled fingers or placing it at the side of your hand. Your index finger should be extended, while your middle, ring, and pinky fingers should be curled into your palm.
#
# ## 2: Determine the palm orientation for the ASL sign for 'Z'.
# The palm of your hand should face slightly forward. This is important because the movement of the sign will involve rotating your wrist slightly as you make the 'Z' shape in the air.
#
# ## 3: Learn the movement to sign 'Z' in ASL.
# With your hand configured and your palm oriented properly, you will use your extended index finger to draw a 'Z' shape in the air. Start from the top-left and move your index finger diagonally down to the bottom-right, tracing the shape of a 'Z'. As you make this movement, your palm will naturally rotate with the motion.
#
# ## 4: Combine the hand configuration, palm orientation, and movement to sign 'Z'.
# Putting it all together: Hold your hand with your thumb folded against your curled fingers (or at the side), your index finger extended, and your other fingers curled into your palm. Orient your palm to face slightly forward. Then, move your extended index finger in a 'Z' shape from top-left to bottom-right in the air, allowing your
#   Faithfulness: 1
#   Answer Relevance: 1
#   Context Relevance: 1
#
# Average Scores:
# Faithfulness: 0.94
# Answer Relevance: 0.94
# Context Relevance: 0.75

# %%
# Plot
labels = ["Faithfulness", "Answer Relevance", "Context Relevance"]
values = [faithfulness_avg, relevance_avg, context_avg]

_, ax = plt.subplots()
ax.bar(labels, values)
ax.set_ylim(0, 1)
ax.set_ylabel("Average Score")
ax.set_xlabel("Evaluation Metric")
ax.set_title("ASL Evaluation Scores")
plt.show()

# %% [markdown]
# Testing speed of description generation

# %%
import time
import string
# --- Generate all 26 ASL letter descriptions ---
start = time.perf_counter()

descriptions = {
    letter: generate_asl_description(letter).strip()
    for letter in string.ascii_uppercase
}

elapsed = time.perf_counter() - start
print(f"Finished in {elapsed:.2f} s")
# Out:
# Finished in 81.44 s
